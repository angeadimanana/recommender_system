# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/recommender_system
# Out:
# /content/drive/MyDrive/recommender_system

# %%
# !git config user.name "angeadimanana"
# !git config user.mail "ange.adimanana@univ-antananarivo.mg"

# %%
# !git checkout -b feature_branch_ange
# Out:
# Switched to a new branch 'feature_branch_ange'

# %%
# !git push -u origin feature_branch_ange
# Out:
# Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote:
# remote: Create a pull request for 'feature_branch_ange' on GitHub by visiting:
# remote:      https://github.com/angeadimanana/recommender_system/pull/new/feature_branch_ange
# remote:
# To https://github.com/angeadimanana/recommender_system.git
#  * [new branch]      feature_branch_ange -> feature_branch_ange
# Branch 'feature_branch_ange' set up to track remote branch 'feature_branch_ange' from 'origin'.

# %%
# !git add .

# %%
# !git commit -m "fix code"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@902053e8a35f.(none)')

# %%
# !git config --global user.email "ange.adimanana@univ-antananarivo.mg"
# !git config --global user.name "angeadimanana"
